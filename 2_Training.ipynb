# %% [markdown]
# # Computer Vision Nanodegree
#
# ## Project: Image Captioning
#
# ---
#
# In this notebook, you will train your CNN-RNN model.
#
# You are welcome and encouraged to try out many different architectures and hyperparameters when searching for a good model.
#
# This does have the potential to make the project quite messy!  Before submitting your project, make sure that you clean up:
# - the code you write in this notebook.  The notebook should describe how to train a single CNN-RNN architecture, corresponding to your final choice of hyperparameters.  You should structure the notebook so that the reviewer can replicate your results by running the code in this notebook.
# - the output of the code cell in **Step 2**.  The output should show the output obtained when training the model from scratch.
#
# This notebook **will be graded**.
#
# Feel free to use the links below to navigate the notebook:
# - [Step 1](#step1): Training Setup
# - [Step 2](#step2): Train your Model
# - [Step 3](#step3): (Optional) Validate your Model

# %% [markdown]
# <a id='step1'></a>
# ## Step 1: Training Setup
#
# In this step of the notebook, you will customize the training of your CNN-RNN model by specifying hyperparameters and setting other options that are important to the training procedure.  The values you set now will be used when training your model in **Step 2** below.
#
# You should only amend blocks of code that are preceded by a `TODO` statement.  **Any code blocks that are not preceded by a `TODO` statement should not be modified**.
#
# ### Task #1
#
# Begin by setting the following variables:
# - `batch_size` - the batch size of each training batch.  It is the number of image-caption pairs used to amend the model weights in each training step.
# - `vocab_threshold` - the minimum word count threshold.  Note that a larger threshold will result in a smaller vocabulary, whereas a smaller threshold will include rarer words and result in a larger vocabulary.
# - `vocab_from_file` - a Boolean that decides whether to load the vocabulary from file.
# - `embed_size` - the dimensionality of the image and word embeddings.
# - `hidden_size` - the number of features in the hidden state of the RNN decoder.
# - `num_epochs` - the number of epochs to train the model.  We recommend that you set `num_epochs=3`, but feel free to increase or decrease this number as you wish.  [This paper](https://arxiv.org/pdf/1502.03044.pdf) trained a captioning model on a single state-of-the-art GPU for 3 days, but you'll soon see that you can get reasonable results in a matter of a few hours!  (_But of course, if you want your model to compete with current research, you will have to train for much longer._)
# - `save_every` - determines how often to save the model weights.  We recommend that you set `save_every=1`, to save the model weights after each epoch.  This way, after the `i`th epoch, the encoder and decoder weights will be saved in the `models/` folder as `encoder-i.pkl` and `decoder-i.pkl`, respectively.
# - `print_every` - determines how often to print the batch loss to the Jupyter notebook while training.  Note that you **will not** observe a monotonic decrease in the loss function while training - this is perfectly fine and completely expected!  You are encouraged to keep this at its default value of `100` to avoid clogging the notebook, but feel free to change it.
# - `log_file` - the name of the text file containing - for every step - how the loss and perplexity evolved during training.
#
# If you're not sure where to begin to set some of the values above, you can peruse [this paper](https://arxiv.org/pdf/1502.03044.pdf) and [this paper](https://arxiv.org/pdf/1411.4555.pdf) for useful guidance!  **To avoid spending too long on this notebook**, you are encouraged to consult these suggested research papers to obtain a strong initial guess for which hyperparameters are likely to work best.  Then, train a single model, and proceed to the next notebook (**3_Inference.ipynb**).  If you are unhappy with your performance, you can return to this notebook to tweak the hyperparameters (and/or the architecture in **model.py**) and re-train your model.
#
# ### Question 1
#
# **Question:** Describe your CNN-RNN architecture in detail.  With this architecture in mind, how did you select the values of the variables in Task 1?  If you consulted a research paper detailing a successful implementation of an image captioning model, please provide the reference.
#
# **Answer:**
#
#
# ### (Optional) Task #2
#
# Note that we have provided a recommended image transform `transform_train` for pre-processing the training images, but you are welcome (and encouraged!) to modify it as you wish.  When modifying this transform, keep in mind that:
# - the images in the dataset have varying heights and widths, and
# - if using a pre-trained model, you must perform the corresponding appropriate normalization.
#
# ### Question 2
#
# **Question:** How did you select the transform in `transform_train`?  If you left the transform at its provided value, why do you think that it is a good choice for your CNN architecture?
#
# **Answer:**
#
# ### Task #3
#
# Next, you will specify a Python list containing the learnable parameters of the model.  For instance, if you decide to make all weights in the decoder trainable, but only want to train the weights in the embedding layer of the encoder, then you should set `params` to something like:
# ```
# params = list(decoder.parameters()) + list(encoder.embed.parameters())
# ```
#
# ### Question 3
#
# **Question:** How did you select the trainable parameters of your architecture?  Why do you think this is a good choice?
#
# **Answer:**
#
# ### Task #4
#
# Finally, you will select an [optimizer](http://pytorch.org/docs/master/optim.html#torch.optim.Optimizer).
#
# ### Question 4
#
# **Question:** How did you select the optimizer used to train your model?
#
# **Answer:**

# %%
import torch
import torch.nn as nn
from torchvision import transforms
import sys
sys.path.append('/opt/cocoapi/PythonAPI')
from pycocotools.coco import COCO
from data_loader import get_loader
from model import EncoderCNN, DecoderRNN
import math


## TODO #1: Select appropriate values for the Python variables below.
batch_size = 10        # batch size
vocab_threshold = 5        # minimum word count threshold
vocab_from_file = False    # if True, load existing vocab file
embed_size = 256           # dimensionality of image and word embeddings
hidden_size = 512          # number of features in hidden state of the RNN decoder
num_epochs = 1            # number of training epochs
save_every = 1             # determines frequency of saving model weights
print_every = 100          # determines window for printing average loss
log_file = 'training_log.txt'       # name of file with saved training loss and perplexity

# (Optional) TODO #2: Amend the image transform below.
transform_train = transforms.Compose([ 
    transforms.Resize(256),                          # smaller edge of image resized to 256
    transforms.RandomCrop(224),                      # get 224x224 crop from random location
    transforms.RandomHorizontalFlip(),               # horizontally flip image with probability=0.5
    transforms.ToTensor(),                           # convert the PIL Image to a tensor
    transforms.Normalize((0.485, 0.456, 0.406),      # normalize image for pre-trained model
                         (0.229, 0.224, 0.225))])

# Build data loader.
data_loader = get_loader(transform=transform_train,
                         mode='train',
                         batch_size=batch_size,
                         vocab_threshold=vocab_threshold,
                         vocab_from_file=vocab_from_file)

# The size of the vocabulary.
vocab_size = len(data_loader.dataset.vocab)

# Initialize the encoder and decoder. 
encoder = EncoderCNN(embed_size)
decoder = DecoderRNN(embed_size, hidden_size, vocab_size)

# Move models to GPU if CUDA is available. 
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
encoder.to(device)
decoder.to(device)

# Define the loss function. 
criterion = nn.CrossEntropyLoss().cuda() if torch.cuda.is_available() else nn.CrossEntropyLoss()

# TODO #3: Specify the learnable parameters of the model.
params = decoder.parameters()

# TODO #4: Define the optimizer.
optimizer = torch.optim.Adam(params,lr=0.0001)

# Set the total number of training steps per epoch.
total_step = math.ceil(len(data_loader.dataset.caption_lengths) / data_loader.batch_sampler.batch_size)
# Out:
# loading annotations into memory...
# Done (t=0.77s)
# creating index...
# index created!
# [0/414113] Tokenizing captions...
# [100000/414113] Tokenizing captions...
# [200000/414113] Tokenizing captions...
# [300000/414113] Tokenizing captions...
# [400000/414113] Tokenizing captions...
# loading annotations into memory...
# Done (t=0.80s)
# creating index...
#   0%|          | 1378/414113 [00:00<01:00, 6859.01it/s]
# index created!
# Obtaining caption lengths...
# 100%|██████████| 414113/414113 [01:02<00:00, 6677.35it/s]

# %% [markdown]
# <a id='step2'></a>
# ## Step 2: Train your Model
#
# Once you have executed the code cell in **Step 1**, the training procedure below should run without issue.
#
# It is completely fine to leave the code cell below as-is without modifications to train your model.  However, if you would like to modify the code used to train the model below, you must ensure that your changes are easily parsed by your reviewer.  In other words, make sure to provide appropriate comments to describe how your code works!
#
# You may find it useful to load saved weights to resume training.  In that case, note the names of the files containing the encoder and decoder weights that you'd like to load (`encoder_file` and `decoder_file`).  Then you can load the weights by using the lines below:
#
# ```python
# # Load pre-trained weights before resuming training.
# encoder.load_state_dict(torch.load(os.path.join('./models', encoder_file)))
# decoder.load_state_dict(torch.load(os.path.join('./models', decoder_file)))
# ```
#
# While trying out parameters, make sure to take extensive notes and record the settings that you used in your various training runs.  In particular, you don't want to encounter a situation where you've trained a model for several hours but can't remember what settings you used :).
#
# ### A Note on Tuning Hyperparameters
#
# To figure out how well your model is doing, you can look at how the training loss and perplexity evolve during training - and for the purposes of this project, you are encouraged to amend the hyperparameters based on this information.
#
# However, this will not tell you if your model is overfitting to the training data, and, unfortunately, overfitting is a problem that is commonly encountered when training image captioning models.
#
# For this project, you need not worry about overfitting. **This project does not have strict requirements regarding the performance of your model**, and you just need to demonstrate that your model has learned **_something_** when you generate captions on the test data.  For now, we strongly encourage you to train your model for the suggested 3 epochs without worrying about performance; then, you should immediately transition to the next notebook in the sequence (**3_Inference.ipynb**) to see how your model performs on the test data.  If your model needs to be changed, you can come back to this notebook, amend hyperparameters (if necessary), and re-train the model.
#
# That said, if you would like to go above and beyond in this project, you can read about some approaches to minimizing overfitting in section 4.3.1 of [this paper](http://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=7505636).  In the next (optional) step of this notebook, we provide some guidance for assessing the performance on the validation dataset.

# %%
num_epochs = 1
#just for test!!

# %%
import torch.utils.data as data
import numpy as np
import os
import requests
import time

# Open the training log file.
f = open(log_file, 'w')

old_time = time.time()
response = requests.request("GET", 
                            "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token", 
                            headers={"Metadata-Flavor":"Google"})

for epoch in range(1, num_epochs+1):
    
    for i_step in range(1, total_step+1):
        
        if time.time() - old_time > 60:
            old_time = time.time()
            requests.request("POST", 
                             "https://nebula.udacity.com/api/v1/remote/keep-alive", 
                             headers={'Authorization': "STAR " + response.text})
        
        # Randomly sample a caption length, and sample indices with that length.
        indices = data_loader.dataset.get_train_indices()
        # Create and assign a batch sampler to retrieve a batch with the sampled indices.
        new_sampler = data.sampler.SubsetRandomSampler(indices=indices)
        data_loader.batch_sampler.sampler = new_sampler
        
        # Obtain the batch.
        images, captions = next(iter(data_loader))

        # Move batch of images and captions to GPU if CUDA is available.
        images = images.to(device)
        captions = captions.to(device)
        
        # Zero the gradients.
        decoder.zero_grad()
        encoder.zero_grad()
        
        # Pass the inputs through the CNN-RNN model.
        features = encoder(images)
        outputs = decoder(features, captions)
        
        # Calculate the batch loss.
        loss = criterion(outputs.view(-1, vocab_size), captions.view(-1))
        
        # Backward pass.
        loss.backward()
        
        # Update the parameters in the optimizer.
        optimizer.step()
            
        # Get training statistics.
        stats = 'Epoch [%d/%d], Step [%d/%d], Loss: %.4f, Perplexity: %5.4f' % (epoch, num_epochs, i_step, total_step, loss.item(), np.exp(loss.item()))
        
        # Print training statistics (on same line).
        print('\r' + stats, end="")
        sys.stdout.flush()
        
        # Print training statistics to file.
        f.write(stats + '\n')
        f.flush()
        
        # Print training statistics (on different line).
        if i_step % print_every == 0:
            print('\r' + stats)
            
    # Save the weights.
    if epoch % save_every == 0:
        torch.save(decoder.state_dict(), os.path.join('./models', 'decoder-%d.pkl' % epoch))
        torch.save(encoder.state_dict(), os.path.join('./models', 'encoder-%d.pkl' % epoch))

# Close the training log file.
f.close()
# Out:
# Epoch [1/1], Step [100/41412], Loss: 5.9741, Perplexity: 393.1311
# Epoch [1/1], Step [200/41412], Loss: 5.2772, Perplexity: 195.8130
# Epoch [1/1], Step [300/41412], Loss: 4.7997, Perplexity: 121.4746
# Epoch [1/1], Step [400/41412], Loss: 5.1357, Perplexity: 169.9865
# Epoch [1/1], Step [500/41412], Loss: 4.8784, Perplexity: 131.4178
# Epoch [1/1], Step [600/41412], Loss: 4.6663, Perplexity: 106.3056
# Epoch [1/1], Step [700/41412], Loss: 4.6951, Perplexity: 109.4150
# Epoch [1/1], Step [800/41412], Loss: 4.3690, Perplexity: 78.96096
# Epoch [1/1], Step [900/41412], Loss: 4.3206, Perplexity: 75.23121
# Epoch [1/1], Step [1000/41412], Loss: 3.9877, Perplexity: 53.9313
# Epoch [1/1], Step [1100/41412], Loss: 4.5593, Perplexity: 95.51646
# Epoch [1/1], Step [1200/41412], Loss: 4.2672, Perplexity: 71.32290
# Epoch [1/1], Step [1300/41412], Loss: 4.1905, Perplexity: 66.05682
# Epoch [1/1], Step [1400/41412], Loss: 3.8864, Perplexity: 48.73348
# Epoch [1/1], Step [1500/41412], Loss: 4.7050, Perplexity: 110.4930
# Epoch [1/1], Step [1600/41412], Loss: 4.6770, Perplexity: 107.4425
# Epoch [1/1], Step [1700/41412], Loss: 4.0483, Perplexity: 57.30275
# Epoch [1/1], Step [1800/41412], Loss: 4.2710, Perplexity: 71.59591
# Epoch [1/1], Step [1900/41412], Loss: 3.8586, Perplexity: 47.39833
# Epoch [1/1], Step [2000/41412], Loss: 3.8696, Perplexity: 47.92258
# Epoch [1/1], Step [2100/41412], Loss: 4.4704, Perplexity: 87.38928
# Epoch [1/1], Step [2200/41412], Loss: 3.8258, Perplexity: 45.87157
# Epoch [1/1], Step [2300/41412], Loss: 4.1610, Perplexity: 64.13680
# Epoch [1/1], Step [2400/41412], Loss: 3.9649, Perplexity: 52.7128
# Epoch [1/1], Step [2500/41412], Loss: 3.5569, Perplexity: 35.0538
# Epoch [1/1], Step [2600/41412], Loss: 3.3777, Perplexity: 29.30302
# Epoch [1/1], Step [2700/41412], Loss: 4.1432, Perplexity: 63.0013
# Epoch [1/1], Step [2800/41412], Loss: 3.5180, Perplexity: 33.71608
# Epoch [1/1], Step [2900/41412], Loss: 3.9855, Perplexity: 53.8120
# Epoch [1/1], Step [3000/41412], Loss: 3.4316, Perplexity: 30.92720
# Epoch [1/1], Step [3100/41412], Loss: 3.7480, Perplexity: 42.43686
# Epoch [1/1], Step [3200/41412], Loss: 4.4230, Perplexity: 83.3438
# Epoch [1/1], Step [3300/41412], Loss: 3.2866, Perplexity: 26.75243
# Epoch [1/1], Step [3400/41412], Loss: 3.2757, Perplexity: 26.4626
# Epoch [1/1], Step [3500/41412], Loss: 3.7276, Perplexity: 41.5801
# Epoch [1/1], Step [3600/41412], Loss: 3.4418, Perplexity: 31.24371
# Epoch [1/1], Step [3700/41412], Loss: 3.6646, Perplexity: 39.03878
# Epoch [1/1], Step [3800/41412], Loss: 3.5929, Perplexity: 36.33771
# Epoch [1/1], Step [3900/41412], Loss: 3.3492, Perplexity: 28.47997
# Epoch [1/1], Step [4000/41412], Loss: 3.6107, Perplexity: 36.99334
# Epoch [1/1], Step [4100/41412], Loss: 3.5936, Perplexity: 36.36322
# Epoch [1/1], Step [4200/41412], Loss: 4.5425, Perplexity: 93.92290
# Epoch [1/1], Step [4300/41412], Loss: 4.3610, Perplexity: 78.3329
# Epoch [1/1], Step [4400/41412], Loss: 3.7233, Perplexity: 41.4027
# Epoch [1/1], Step [4500/41412], Loss: 3.1126, Perplexity: 22.4798
# Epoch [1/1], Step [4600/41412], Loss: 3.3100, Perplexity: 27.38411
# Epoch [1/1], Step [4700/41412], Loss: 3.9021, Perplexity: 49.50637
# Epoch [1/1], Step [4800/41412], Loss: 4.7152, Perplexity: 111.6338
# Epoch [1/1], Step [4900/41412], Loss: 3.3871, Perplexity: 29.5799
# Epoch [1/1], Step [5000/41412], Loss: 3.1952, Perplexity: 24.41443
# Epoch [1/1], Step [5100/41412], Loss: 3.9964, Perplexity: 54.4045
# Epoch [1/1], Step [5200/41412], Loss: 3.2102, Perplexity: 24.78423
# Epoch [1/1], Step [5300/41412], Loss: 3.1450, Perplexity: 23.22066
# Epoch [1/1], Step [5400/41412], Loss: 3.3274, Perplexity: 27.86727
# Epoch [1/1], Step [5500/41412], Loss: 3.6588, Perplexity: 38.81601
# Epoch [1/1], Step [5600/41412], Loss: 3.5410, Perplexity: 34.5027
# Epoch [1/1], Step [5700/41412], Loss: 3.1249, Perplexity: 22.75730
# Epoch [1/1], Step [5800/41412], Loss: 4.0604, Perplexity: 57.9965
# Epoch [1/1], Step [5900/41412], Loss: 3.2529, Perplexity: 25.8651
# Epoch [1/1], Step [6000/41412], Loss: 3.4858, Perplexity: 32.6499
# Epoch [1/1], Step [6100/41412], Loss: 3.0108, Perplexity: 20.3029
# Epoch [1/1], Step [6200/41412], Loss: 3.9279, Perplexity: 50.8014
# Epoch [1/1], Step [6300/41412], Loss: 3.7599, Perplexity: 42.9436
# Epoch [1/1], Step [6400/41412], Loss: 4.4484, Perplexity: 85.4928
# Epoch [1/1], Step [6500/41412], Loss: 3.6800, Perplexity: 39.64623
# Epoch [1/1], Step [6600/41412], Loss: 3.5047, Perplexity: 33.2703
# Epoch [1/1], Step [6700/41412], Loss: 3.7364, Perplexity: 41.9479
# Epoch [1/1], Step [6800/41412], Loss: 3.4840, Perplexity: 32.5902
# Epoch [1/1], Step [6900/41412], Loss: 3.9159, Perplexity: 50.1929
# Epoch [1/1], Step [7000/41412], Loss: 3.6537, Perplexity: 38.6182
# Epoch [1/1], Step [7100/41412], Loss: 3.3546, Perplexity: 28.6336
# Epoch [1/1], Step [7200/41412], Loss: 3.3349, Perplexity: 28.0751
# Epoch [1/1], Step [7300/41412], Loss: 3.8877, Perplexity: 48.7992
# Epoch [1/1], Step [7400/41412], Loss: 3.5490, Perplexity: 34.7770
# Epoch [1/1], Step [7500/41412], Loss: 3.3055, Perplexity: 27.26293
# Epoch [1/1], Step [7600/41412], Loss: 3.0200, Perplexity: 20.49030
# Epoch [1/1], Step [7700/41412], Loss: 3.8680, Perplexity: 47.8477
# Epoch [1/1], Step [7800/41412], Loss: 3.3980, Perplexity: 29.90419
# Epoch [1/1], Step [7900/41412], Loss: 4.2734, Perplexity: 71.76788
# Epoch [1/1], Step [8000/41412], Loss: 3.8233, Perplexity: 45.7535
# Epoch [1/1], Step [8100/41412], Loss: 3.6604, Perplexity: 38.8785
# Epoch [1/1], Step [8200/41412], Loss: 3.4902, Perplexity: 32.79417
# Epoch [1/1], Step [8300/41412], Loss: 3.7592, Perplexity: 42.91359
# Epoch [1/1], Step [8400/41412], Loss: 3.4632, Perplexity: 31.9194
# Epoch [1/1], Step [8500/41412], Loss: 3.4515, Perplexity: 31.5470
# Epoch [1/1], Step [8600/41412], Loss: 3.7902, Perplexity: 44.26662
# Epoch [1/1], Step [8700/41412], Loss: 4.0115, Perplexity: 55.23197
# Epoch [1/1], Step [8800/41412], Loss: 3.4742, Perplexity: 32.2733
# Epoch [1/1], Step [8900/41412], Loss: 3.7474, Perplexity: 42.4127
# Epoch [1/1], Step [9000/41412], Loss: 3.5100, Perplexity: 33.4478
# Epoch [1/1], Step [9100/41412], Loss: 3.7979, Perplexity: 44.6062
# Epoch [1/1], Step [9200/41412], Loss: 3.7484, Perplexity: 42.4525
# Epoch [1/1], Step [9300/41412], Loss: 3.0500, Perplexity: 21.11558
# Epoch [1/1], Step [9400/41412], Loss: 3.9781, Perplexity: 53.4157
# Epoch [1/1], Step [9500/41412], Loss: 3.3540, Perplexity: 28.6156
# Epoch [1/1], Step [9600/41412], Loss: 4.2083, Perplexity: 67.24379
# Epoch [1/1], Step [9700/41412], Loss: 3.5998, Perplexity: 36.5900
# Epoch [1/1], Step [9800/41412], Loss: 3.1264, Perplexity: 22.7920
# Epoch [1/1], Step [9900/41412], Loss: 3.7270, Perplexity: 41.5546
# Epoch [1/1], Step [10000/41412], Loss: 3.6275, Perplexity: 37.6189
# Epoch [1/1], Step [10100/41412], Loss: 4.2512, Perplexity: 70.1867
# Epoch [1/1], Step [10200/41412], Loss: 3.3401, Perplexity: 28.2206
# Epoch [1/1], Step [10300/41412], Loss: 2.9910, Perplexity: 19.90506
# Epoch [1/1], Step [10400/41412], Loss: 2.9739, Perplexity: 19.56818
# Epoch [1/1], Step [10500/41412], Loss: 3.8079, Perplexity: 45.0546
# Epoch [1/1], Step [10600/41412], Loss: 3.6929, Perplexity: 40.1610
# Epoch [1/1], Step [10700/41412], Loss: 3.2597, Perplexity: 26.0406
# Epoch [1/1], Step [10800/41412], Loss: 3.3750, Perplexity: 29.2240
# Epoch [1/1], Step [10900/41412], Loss: 3.5906, Perplexity: 36.2568
# Epoch [1/1], Step [11000/41412], Loss: 3.0824, Perplexity: 21.8103
# Epoch [1/1], Step [11100/41412], Loss: 3.5110, Perplexity: 33.4830
# Epoch [1/1], Step [11200/41412], Loss: 3.5344, Perplexity: 34.2743
# Epoch [1/1], Step [11300/41412], Loss: 3.6040, Perplexity: 36.7448
# Epoch [1/1], Step [11400/41412], Loss: 3.1179, Perplexity: 22.6000
# Epoch [1/1], Step [11500/41412], Loss: 3.1754, Perplexity: 23.9368
# Epoch [1/1], Step [11600/41412], Loss: 3.0535, Perplexity: 21.18960
# Epoch [1/1], Step [11700/41412], Loss: 3.0599, Perplexity: 21.3259
# Epoch [1/1], Step [11800/41412], Loss: 3.2340, Perplexity: 25.3802
# Epoch [1/1], Step [11900/41412], Loss: 3.2473, Perplexity: 25.7205
# Epoch [1/1], Step [12000/41412], Loss: 2.7325, Perplexity: 15.3709
# Epoch [1/1], Step [12100/41412], Loss: 3.0499, Perplexity: 21.1142
# Epoch [1/1], Step [12200/41412], Loss: 2.5704, Perplexity: 13.07040
# Epoch [1/1], Step [12300/41412], Loss: 3.2834, Perplexity: 26.6665
# Epoch [1/1], Step [12400/41412], Loss: 3.6243, Perplexity: 37.5001
# Epoch [1/1], Step [12500/41412], Loss: 4.4153, Perplexity: 82.7047
# Epoch [1/1], Step [12600/41412], Loss: 3.3015, Perplexity: 27.1522
# Epoch [1/1], Step [12700/41412], Loss: 3.6071, Perplexity: 36.8602
# Epoch [1/1], Step [12800/41412], Loss: 3.6828, Perplexity: 39.75581
# Epoch [1/1], Step [12900/41412], Loss: 3.1301, Perplexity: 22.8772
# Epoch [1/1], Step [13000/41412], Loss: 3.2883, Perplexity: 26.79737
# Epoch [1/1], Step [13100/41412], Loss: 3.0812, Perplexity: 21.7848
# Epoch [1/1], Step [13200/41412], Loss: 3.2430, Perplexity: 25.61009
# Epoch [1/1], Step [13300/41412], Loss: 3.6954, Perplexity: 40.2604
# Epoch [1/1], Step [13400/41412], Loss: 3.2106, Perplexity: 24.7935
# Epoch [1/1], Step [13500/41412], Loss: 3.3018, Perplexity: 27.1606
# Epoch [1/1], Step [13600/41412], Loss: 3.1085, Perplexity: 22.3876
# Epoch [1/1], Step [13700/41412], Loss: 3.3277, Perplexity: 27.8733
# Epoch [1/1], Step [13800/41412], Loss: 3.1728, Perplexity: 23.8736
# Epoch [1/1], Step [13900/41412], Loss: 3.5768, Perplexity: 35.7591
# Epoch [1/1], Step [14000/41412], Loss: 3.1879, Perplexity: 24.2386
# Epoch [1/1], Step [14100/41412], Loss: 2.9916, Perplexity: 19.9178
# Epoch [1/1], Step [14200/41412], Loss: 3.2481, Perplexity: 25.74195
# Epoch [1/1], Step [14300/41412], Loss: 2.7105, Perplexity: 15.0369
# Epoch [1/1], Step [14400/41412], Loss: 3.1912, Perplexity: 24.3169
# Epoch [1/1], Step [14500/41412], Loss: 3.8549, Perplexity: 47.2229
# Epoch [1/1], Step [14600/41412], Loss: 3.4320, Perplexity: 30.9386
# Epoch [1/1], Step [14700/41412], Loss: 3.4325, Perplexity: 30.9546
# Epoch [1/1], Step [14800/41412], Loss: 3.2912, Perplexity: 26.8758
# Epoch [1/1], Step [14900/41412], Loss: 3.2622, Perplexity: 26.1075
# Epoch [1/1], Step [15000/41412], Loss: 3.6245, Perplexity: 37.5052
# Epoch [1/1], Step [15100/41412], Loss: 3.3821, Perplexity: 29.4322
# Epoch [1/1], Step [15200/41412], Loss: 3.5657, Perplexity: 35.3634
# Epoch [1/1], Step [15300/41412], Loss: 4.1659, Perplexity: 64.4517
# Epoch [1/1], Step [15400/41412], Loss: 3.2254, Perplexity: 25.1646
# Epoch [1/1], Step [15500/41412], Loss: 3.5081, Perplexity: 33.3858
# Epoch [1/1], Step [15600/41412], Loss: 3.1846, Perplexity: 24.1571
# Epoch [1/1], Step [15700/41412], Loss: 3.1380, Perplexity: 23.0570
# Epoch [1/1], Step [15800/41412], Loss: 2.8526, Perplexity: 17.3331
# Epoch [1/1], Step [15900/41412], Loss: 3.0181, Perplexity: 20.4530
# Epoch [1/1], Step [16000/41412], Loss: 3.2923, Perplexity: 26.90555
# Epoch [1/1], Step [16100/41412], Loss: 3.6283, Perplexity: 37.64886
# Epoch [1/1], Step [16200/41412], Loss: 3.6645, Perplexity: 39.0354
# Epoch [1/1], Step [16300/41412], Loss: 2.6999, Perplexity: 14.8782
# Epoch [1/1], Step [16400/41412], Loss: 3.2140, Perplexity: 24.8783
# Epoch [1/1], Step [16500/41412], Loss: 3.7127, Perplexity: 40.9645
# Epoch [1/1], Step [16600/41412], Loss: 3.3655, Perplexity: 28.9468
# Epoch [1/1], Step [16700/41412], Loss: 4.2531, Perplexity: 70.3196
# Epoch [1/1], Step [16800/41412], Loss: 2.7116, Perplexity: 15.0539
# Epoch [1/1], Step [16900/41412], Loss: 3.2633, Perplexity: 26.1369
# Epoch [1/1], Step [17000/41412], Loss: 3.8941, Perplexity: 49.1130
# Epoch [1/1], Step [17100/41412], Loss: 3.8196, Perplexity: 45.5878
# Epoch [1/1], Step [17200/41412], Loss: 3.5006, Perplexity: 33.13531
# Epoch [1/1], Step [17300/41412], Loss: 2.8113, Perplexity: 16.6323
# Epoch [1/1], Step [17400/41412], Loss: 3.2703, Perplexity: 26.3187
# Epoch [1/1], Step [17500/41412], Loss: 3.1377, Perplexity: 23.05095
# Epoch [1/1], Step [17600/41412], Loss: 3.8993, Perplexity: 49.3697
# Epoch [1/1], Step [17700/41412], Loss: 3.1669, Perplexity: 23.7349
# Epoch [1/1], Step [17800/41412], Loss: 3.9380, Perplexity: 51.3166
# Epoch [1/1], Step [17900/41412], Loss: 3.2793, Perplexity: 26.5570
# Epoch [1/1], Step [18000/41412], Loss: 3.3061, Perplexity: 27.2774
# Epoch [1/1], Step [18100/41412], Loss: 3.1761, Perplexity: 23.9526
# Epoch [1/1], Step [18200/41412], Loss: 3.4737, Perplexity: 32.2550
# Epoch [1/1], Step [18300/41412], Loss: 3.8014, Perplexity: 44.76591
# Epoch [1/1], Step [18400/41412], Loss: 3.5704, Perplexity: 35.5304
# Epoch [1/1], Step [18500/41412], Loss: 3.9543, Perplexity: 52.1569
# Epoch [1/1], Step [18600/41412], Loss: 2.7756, Perplexity: 16.0475
# Epoch [1/1], Step [18700/41412], Loss: 3.2225, Perplexity: 25.09147
# Epoch [1/1], Step [18800/41412], Loss: 3.2060, Perplexity: 24.6813
# Epoch [1/1], Step [18900/41412], Loss: 2.9181, Perplexity: 18.5060
# Epoch [1/1], Step [19000/41412], Loss: 3.1675, Perplexity: 23.7474
# Epoch [1/1], Step [19100/41412], Loss: 3.5921, Perplexity: 36.3099
# Epoch [1/1], Step [19200/41412], Loss: 3.0941, Perplexity: 22.0679
# Epoch [1/1], Step [19300/41412], Loss: 2.8274, Perplexity: 16.9015
# Epoch [1/1], Step [19400/41412], Loss: 2.9992, Perplexity: 20.0700
# Epoch [1/1], Step [19500/41412], Loss: 3.4687, Perplexity: 32.0935
# Epoch [1/1], Step [19600/41412], Loss: 3.1259, Perplexity: 22.7815
# Epoch [1/1], Step [19700/41412], Loss: 3.1656, Perplexity: 23.7027
# Epoch [1/1], Step [19800/41412], Loss: 3.2565, Perplexity: 25.95787
# Epoch [1/1], Step [19900/41412], Loss: 2.6922, Perplexity: 14.7645
# Epoch [1/1], Step [20000/41412], Loss: 3.1153, Perplexity: 22.5401
# Epoch [1/1], Step [20100/41412], Loss: 3.3324, Perplexity: 28.0055
# Epoch [1/1], Step [20200/41412], Loss: 3.0456, Perplexity: 21.02334
# Epoch [1/1], Step [20300/41412], Loss: 3.1658, Perplexity: 23.7078
# Epoch [1/1], Step [20400/41412], Loss: 3.4907, Perplexity: 32.8094
# Epoch [1/1], Step [20500/41412], Loss: 3.0579, Perplexity: 21.2836
# Epoch [1/1], Step [20600/41412], Loss: 3.5051, Perplexity: 33.2858
# Epoch [1/1], Step [20700/41412], Loss: 3.9218, Perplexity: 50.4923
# Epoch [1/1], Step [20800/41412], Loss: 2.9950, Perplexity: 19.9859
# Epoch [1/1], Step [20900/41412], Loss: 4.3902, Perplexity: 80.6557
# Epoch [1/1], Step [21000/41412], Loss: 3.4021, Perplexity: 30.0279
# Epoch [1/1], Step [21100/41412], Loss: 2.9814, Perplexity: 19.7163
# Epoch [1/1], Step [21200/41412], Loss: 2.7997, Perplexity: 16.4399
# Epoch [1/1], Step [21300/41412], Loss: 3.6708, Perplexity: 39.2842
# Epoch [1/1], Step [21400/41412], Loss: 2.7521, Perplexity: 15.6763
# Epoch [1/1], Step [21500/41412], Loss: 2.9714, Perplexity: 19.5195
# Epoch [1/1], Step [21600/41412], Loss: 3.4784, Perplexity: 32.4089
# Epoch [1/1], Step [21700/41412], Loss: 3.2007, Perplexity: 24.5499
# Epoch [1/1], Step [21800/41412], Loss: 3.1063, Perplexity: 22.3371
# Epoch [1/1], Step [21900/41412], Loss: 3.2186, Perplexity: 24.9941
# Epoch [1/1], Step [22000/41412], Loss: 3.5947, Perplexity: 36.4047
# Epoch [1/1], Step [22100/41412], Loss: 3.3571, Perplexity: 28.7051
# Epoch [1/1], Step [22200/41412], Loss: 3.1151, Perplexity: 22.5367
# Epoch [1/1], Step [22300/41412], Loss: 2.9811, Perplexity: 19.7100
# Epoch [1/1], Step [22400/41412], Loss: 4.0807, Perplexity: 59.1894
# Epoch [1/1], Step [22500/41412], Loss: 3.1419, Perplexity: 23.1481
# Epoch [1/1], Step [22600/41412], Loss: 2.9753, Perplexity: 19.5964
# Epoch [1/1], Step [22700/41412], Loss: 3.2277, Perplexity: 25.2206
# Epoch [1/1], Step [22800/41412], Loss: 3.4255, Perplexity: 30.7376
# Epoch [1/1], Step [22900/41412], Loss: 3.6983, Perplexity: 40.3794
# Epoch [1/1], Step [23000/41412], Loss: 2.8678, Perplexity: 17.5991
# Epoch [1/1], Step [23100/41412], Loss: 3.2734, Perplexity: 26.4013
# Epoch [1/1], Step [23200/41412], Loss: 2.8983, Perplexity: 18.1434
# Epoch [1/1], Step [23300/41412], Loss: 2.8597, Perplexity: 17.4568
# Epoch [1/1], Step [23400/41412], Loss: 3.7786, Perplexity: 43.7557
# Epoch [1/1], Step [23500/41412], Loss: 3.3960, Perplexity: 29.8433
# Epoch [1/1], Step [23600/41412], Loss: 3.6705, Perplexity: 39.2729
# Epoch [1/1], Step [23700/41412], Loss: 3.2385, Perplexity: 25.4947
# Epoch [1/1], Step [23800/41412], Loss: 3.1512, Perplexity: 23.3648
# Epoch [1/1], Step [23900/41412], Loss: 3.1092, Perplexity: 22.4042
# Epoch [1/1], Step [24000/41412], Loss: 3.1450, Perplexity: 23.2191
# Epoch [1/1], Step [24100/41412], Loss: 3.2049, Perplexity: 24.6520
# Epoch [1/1], Step [24200/41412], Loss: 2.8657, Perplexity: 17.5618
# Epoch [1/1], Step [24300/41412], Loss: 3.5160, Perplexity: 33.6482
# Epoch [1/1], Step [24400/41412], Loss: 3.0836, Perplexity: 21.8364
# Epoch [1/1], Step [24500/41412], Loss: 3.4449, Perplexity: 31.3413
# Epoch [1/1], Step [24600/41412], Loss: 3.1922, Perplexity: 24.3413
# Epoch [1/1], Step [24700/41412], Loss: 2.8163, Perplexity: 16.7141
# Epoch [1/1], Step [24800/41412], Loss: 3.0141, Perplexity: 20.3701
# Epoch [1/1], Step [24900/41412], Loss: 2.9411, Perplexity: 18.9376
# Epoch [1/1], Step [25000/41412], Loss: 3.2017, Perplexity: 24.57527
# Epoch [1/1], Step [25100/41412], Loss: 2.8988, Perplexity: 18.1518
# Epoch [1/1], Step [25200/41412], Loss: 3.0547, Perplexity: 21.2154
# Epoch [1/1], Step [25300/41412], Loss: 3.1362, Perplexity: 23.0155
# Epoch [1/1], Step [25400/41412], Loss: 2.7017, Perplexity: 14.9044
# Epoch [1/1], Step [25500/41412], Loss: 2.8139, Perplexity: 16.6750
# Epoch [1/1], Step [25600/41412], Loss: 3.0584, Perplexity: 21.29408
# Epoch [1/1], Step [25700/41412], Loss: 3.1709, Perplexity: 23.8287
# Epoch [1/1], Step [25800/41412], Loss: 2.7917, Perplexity: 16.3088
# Epoch [1/1], Step [25900/41412], Loss: 2.7942, Perplexity: 16.3498
# Epoch [1/1], Step [26000/41412], Loss: 3.5131, Perplexity: 33.5525
# Epoch [1/1], Step [26100/41412], Loss: 3.4762, Perplexity: 32.3363
# Epoch [1/1], Step [26200/41412], Loss: 3.2650, Perplexity: 26.1795
# Epoch [1/1], Step [26300/41412], Loss: 2.9219, Perplexity: 18.5768
# Epoch [1/1], Step [26400/41412], Loss: 3.1197, Perplexity: 22.6395
# Epoch [1/1], Step [26500/41412], Loss: 2.1500, Perplexity: 8.58499
# Epoch [1/1], Step [26600/41412], Loss: 3.2594, Perplexity: 26.0328
# Epoch [1/1], Step [26700/41412], Loss: 3.0277, Perplexity: 20.6502
# Epoch [1/1], Step [26800/41412], Loss: 3.6741, Perplexity: 39.4145
# Epoch [1/1], Step [26900/41412], Loss: 3.2456, Perplexity: 25.6777
# Epoch [1/1], Step [27000/41412], Loss: 2.8956, Perplexity: 18.0944
# Epoch [1/1], Step [27100/41412], Loss: 3.2862, Perplexity: 26.7401
# Epoch [1/1], Step [27200/41412], Loss: 3.2503, Perplexity: 25.7989
# Epoch [1/1], Step [27300/41412], Loss: 3.3171, Perplexity: 27.5803
# Epoch [1/1], Step [27400/41412], Loss: 2.9852, Perplexity: 19.7898
# Epoch [1/1], Step [27500/41412], Loss: 2.7656, Perplexity: 15.8889
# Epoch [1/1], Step [27600/41412], Loss: 3.2336, Perplexity: 25.3699
# Epoch [1/1], Step [27700/41412], Loss: 2.8151, Perplexity: 16.6944
# Epoch [1/1], Step [27800/41412], Loss: 3.1708, Perplexity: 23.8277
# Epoch [1/1], Step [27900/41412], Loss: 3.8895, Perplexity: 48.8867
# Epoch [1/1], Step [28000/41412], Loss: 3.0421, Perplexity: 20.9487
# Epoch [1/1], Step [28100/41412], Loss: 2.9057, Perplexity: 18.2774
# Epoch [1/1], Step [28200/41412], Loss: 3.2812, Perplexity: 26.60823
# Epoch [1/1], Step [28300/41412], Loss: 2.7888, Perplexity: 16.26150
# Epoch [1/1], Step [28400/41412], Loss: 3.3757, Perplexity: 29.2452
# Epoch [1/1], Step [28500/41412], Loss: 3.0113, Perplexity: 20.3147
# Epoch [1/1], Step [28600/41412], Loss: 2.7957, Perplexity: 16.37421
# Epoch [1/1], Step [28700/41412], Loss: 3.0807, Perplexity: 21.7738
# Epoch [1/1], Step [28800/41412], Loss: 3.2886, Perplexity: 26.8056
# Epoch [1/1], Step [28900/41412], Loss: 3.4725, Perplexity: 32.2187
# Epoch [1/1], Step [29000/41412], Loss: 3.1580, Perplexity: 23.5245
# Epoch [1/1], Step [29100/41412], Loss: 3.1929, Perplexity: 24.35856
# Epoch [1/1], Step [29200/41412], Loss: 3.0318, Perplexity: 20.73523
# Epoch [1/1], Step [29300/41412], Loss: 3.0221, Perplexity: 20.5346
# Epoch [1/1], Step [29400/41412], Loss: 2.6633, Perplexity: 14.34349
# Epoch [1/1], Step [29500/41412], Loss: 2.6883, Perplexity: 14.7065
# Epoch [1/1], Step [29600/41412], Loss: 3.0592, Perplexity: 21.3111
# Epoch [1/1], Step [29700/41412], Loss: 3.0539, Perplexity: 21.19844
# Epoch [1/1], Step [29800/41412], Loss: 2.7760, Perplexity: 16.0541
# Epoch [1/1], Step [29900/41412], Loss: 3.6300, Perplexity: 37.7134
# Epoch [1/1], Step [30000/41412], Loss: 3.3277, Perplexity: 27.8747
# Epoch [1/1], Step [30100/41412], Loss: 2.7624, Perplexity: 15.83854
# Epoch [1/1], Step [30200/41412], Loss: 2.9315, Perplexity: 18.7554
# Epoch [1/1], Step [30300/41412], Loss: 3.2494, Perplexity: 25.7746
# Epoch [1/1], Step [30400/41412], Loss: 2.7722, Perplexity: 15.9937
# Epoch [1/1], Step [30500/41412], Loss: 3.0470, Perplexity: 21.0528
# Epoch [1/1], Step [30600/41412], Loss: 2.7559, Perplexity: 15.7352
# Epoch [1/1], Step [30700/41412], Loss: 2.9434, Perplexity: 18.9805
# Epoch [1/1], Step [30800/41412], Loss: 2.7262, Perplexity: 15.2741
# Epoch [1/1], Step [30900/41412], Loss: 3.0189, Perplexity: 20.4689
# Epoch [1/1], Step [31000/41412], Loss: 2.9999, Perplexity: 20.0832
# Epoch [1/1], Step [31100/41412], Loss: 3.2638, Perplexity: 26.1475
# Epoch [1/1], Step [31200/41412], Loss: 3.4927, Perplexity: 32.87323
# Epoch [1/1], Step [31300/41412], Loss: 2.9992, Perplexity: 20.0699
# Epoch [1/1], Step [31400/41412], Loss: 3.0680, Perplexity: 21.4981
# Epoch [1/1], Step [31500/41412], Loss: 3.8605, Perplexity: 47.4880
# Epoch [1/1], Step [31600/41412], Loss: 3.1340, Perplexity: 22.9667
# Epoch [1/1], Step [31700/41412], Loss: 3.0305, Perplexity: 20.70793
# Epoch [1/1], Step [31800/41412], Loss: 3.0013, Perplexity: 20.1124
# Epoch [1/1], Step [31900/41412], Loss: 3.6308, Perplexity: 37.74447
# Epoch [1/1], Step [32000/41412], Loss: 2.5950, Perplexity: 13.3968
# Epoch [1/1], Step [32100/41412], Loss: 2.9695, Perplexity: 19.4827
# Epoch [1/1], Step [32200/41412], Loss: 3.0740, Perplexity: 21.6273
# Epoch [1/1], Step [32300/41412], Loss: 3.1001, Perplexity: 22.1991
# Epoch [1/1], Step [32400/41412], Loss: 3.2240, Perplexity: 25.1288
# Epoch [1/1], Step [32500/41412], Loss: 3.2886, Perplexity: 26.8063
# Epoch [1/1], Step [32600/41412], Loss: 3.3615, Perplexity: 28.8330
# Epoch [1/1], Step [32700/41412], Loss: 2.9663, Perplexity: 19.4199
# Epoch [1/1], Step [32800/41412], Loss: 2.5432, Perplexity: 12.7199
# Epoch [1/1], Step [32900/41412], Loss: 3.4102, Perplexity: 30.2723
# Epoch [1/1], Step [33000/41412], Loss: 2.8697, Perplexity: 17.6316
# Epoch [1/1], Step [33100/41412], Loss: 3.4987, Perplexity: 33.0720
# Epoch [1/1], Step [33200/41412], Loss: 2.4205, Perplexity: 11.2514
# Epoch [1/1], Step [33300/41412], Loss: 2.9469, Perplexity: 19.0462
# Epoch [1/1], Step [33400/41412], Loss: 2.7206, Perplexity: 15.1901
# Epoch [1/1], Step [33500/41412], Loss: 3.4137, Perplexity: 30.3770
# Epoch [1/1], Step [33600/41412], Loss: 2.9899, Perplexity: 19.8841
# Epoch [1/1], Step [33700/41412], Loss: 3.6030, Perplexity: 36.7095
# Epoch [1/1], Step [33800/41412], Loss: 3.6211, Perplexity: 37.3769
# Epoch [1/1], Step [33900/41412], Loss: 3.3638, Perplexity: 28.89877
# Epoch [1/1], Step [34000/41412], Loss: 3.3266, Perplexity: 27.8431
# Epoch [1/1], Step [34100/41412], Loss: 3.4133, Perplexity: 30.3643
# Epoch [1/1], Step [34200/41412], Loss: 3.4523, Perplexity: 31.5715
# Epoch [1/1], Step [34300/41412], Loss: 3.8120, Perplexity: 45.2388
# Epoch [1/1], Step [34400/41412], Loss: 3.4327, Perplexity: 30.9608
# Epoch [1/1], Step [34500/41412], Loss: 3.1385, Perplexity: 23.0683
# Epoch [1/1], Step [34600/41412], Loss: 2.7701, Perplexity: 15.9609
# Epoch [1/1], Step [34700/41412], Loss: 3.0683, Perplexity: 21.5043
# Epoch [1/1], Step [34800/41412], Loss: 3.3325, Perplexity: 28.0080
# Epoch [1/1], Step [34900/41412], Loss: 3.4031, Perplexity: 30.0563
# Epoch [1/1], Step [35000/41412], Loss: 3.5964, Perplexity: 36.4677
# Epoch [1/1], Step [35100/41412], Loss: 2.9300, Perplexity: 18.7284
# Epoch [1/1], Step [35200/41412], Loss: 3.3214, Perplexity: 27.6987
# Epoch [1/1], Step [35300/41412], Loss: 2.9088, Perplexity: 18.3357
# Epoch [1/1], Step [35400/41412], Loss: 2.8696, Perplexity: 17.6291
# Epoch [1/1], Step [35500/41412], Loss: 3.2101, Perplexity: 24.78167
# Epoch [1/1], Step [35600/41412], Loss: 2.7118, Perplexity: 15.0557
# Epoch [1/1], Step [35700/41412], Loss: 3.7153, Perplexity: 41.0714
# Epoch [1/1], Step [35800/41412], Loss: 3.7476, Perplexity: 42.4185
# Epoch [1/1], Step [35900/41412], Loss: 3.4851, Perplexity: 32.6263
# Epoch [1/1], Step [36000/41412], Loss: 2.6219, Perplexity: 13.7625
# Epoch [1/1], Step [36100/41412], Loss: 2.9444, Perplexity: 18.9995
# Epoch [1/1], Step [36200/41412], Loss: 3.5407, Perplexity: 34.4917
# Epoch [1/1], Step [36300/41412], Loss: 3.2118, Perplexity: 24.8241
# Epoch [1/1], Step [36400/41412], Loss: 3.6164, Perplexity: 37.2040
# Epoch [1/1], Step [36500/41412], Loss: 3.6615, Perplexity: 38.9203
# Epoch [1/1], Step [36600/41412], Loss: 3.1774, Perplexity: 23.9836
# Epoch [1/1], Step [36700/41412], Loss: 3.1481, Perplexity: 23.2922
# Epoch [1/1], Step [36800/41412], Loss: 3.2802, Perplexity: 26.5814
# Epoch [1/1], Step [36900/41412], Loss: 2.7116, Perplexity: 15.0534
# Epoch [1/1], Step [37000/41412], Loss: 3.6792, Perplexity: 39.6130
# Epoch [1/1], Step [37100/41412], Loss: 3.2015, Perplexity: 24.5694
# Epoch [1/1], Step [37200/41412], Loss: 3.5010, Perplexity: 33.1497
# Epoch [1/1], Step [37300/41412], Loss: 2.9230, Perplexity: 18.5970
# Epoch [1/1], Step [37400/41412], Loss: 3.0276, Perplexity: 20.6484
# Epoch [1/1], Step [37500/41412], Loss: 2.9748, Perplexity: 19.5861
# Epoch [1/1], Step [37600/41412], Loss: 3.1998, Perplexity: 24.5279
# Epoch [1/1], Step [37700/41412], Loss: 3.0069, Perplexity: 20.2243
# Epoch [1/1], Step [37800/41412], Loss: 3.4123, Perplexity: 30.3358
# Epoch [1/1], Step [37900/41412], Loss: 2.7161, Perplexity: 15.1209
# Epoch [1/1], Step [38000/41412], Loss: 3.3335, Perplexity: 28.0361
# Epoch [1/1], Step [38100/41412], Loss: 3.0766, Perplexity: 21.6836
# Epoch [1/1], Step [38200/41412], Loss: 2.5784, Perplexity: 13.1765
# Epoch [1/1], Step [38300/41412], Loss: 3.1590, Perplexity: 23.5478
# Epoch [1/1], Step [38400/41412], Loss: 3.0389, Perplexity: 20.8819
# Epoch [1/1], Step [38500/41412], Loss: 3.0228, Perplexity: 20.5497
# Epoch [1/1], Step [38600/41412], Loss: 3.0890, Perplexity: 21.9550
# Epoch [1/1], Step [38700/41412], Loss: 4.2724, Perplexity: 71.6954
# Epoch [1/1], Step [38800/41412], Loss: 3.2525, Perplexity: 25.8554
# Epoch [1/1], Step [38900/41412], Loss: 2.9183, Perplexity: 18.5099
# Epoch [1/1], Step [39000/41412], Loss: 3.1439, Perplexity: 23.1937
# Epoch [1/1], Step [39100/41412], Loss: 3.2278, Perplexity: 25.2241
# Epoch [1/1], Step [39200/41412], Loss: 2.7552, Perplexity: 15.7249
# Epoch [1/1], Step [39300/41412], Loss: 2.9311, Perplexity: 18.7488
# Epoch [1/1], Step [39400/41412], Loss: 3.2951, Perplexity: 26.9792
# Epoch [1/1], Step [39500/41412], Loss: 3.1133, Perplexity: 22.4961
# Epoch [1/1], Step [39600/41412], Loss: 3.2224, Perplexity: 25.0884
# Epoch [1/1], Step [39700/41412], Loss: 3.2822, Perplexity: 26.6338
# Epoch [1/1], Step [39800/41412], Loss: 3.3372, Perplexity: 28.1405
# Epoch [1/1], Step [39900/41412], Loss: 3.0339, Perplexity: 20.7777
# Epoch [1/1], Step [40000/41412], Loss: 3.7779, Perplexity: 43.7234
# Epoch [1/1], Step [40100/41412], Loss: 2.9496, Perplexity: 19.0983
# Epoch [1/1], Step [40200/41412], Loss: 2.7635, Perplexity: 15.8556
# Epoch [1/1], Step [40300/41412], Loss: 2.8911, Perplexity: 18.0139
# Epoch [1/1], Step [40400/41412], Loss: 3.1368, Perplexity: 23.0300
# Epoch [1/1], Step [40500/41412], Loss: 3.0757, Perplexity: 21.6641
# Epoch [1/1], Step [40600/41412], Loss: 3.3748, Perplexity: 29.2178
# Epoch [1/1], Step [40700/41412], Loss: 2.8489, Perplexity: 17.2682
# Epoch [1/1], Step [40800/41412], Loss: 3.0393, Perplexity: 20.8914
# Epoch [1/1], Step [40900/41412], Loss: 3.9586, Perplexity: 52.3857
# Epoch [1/1], Step [41000/41412], Loss: 2.6700, Perplexity: 14.4404
# Epoch [1/1], Step [41100/41412], Loss: 2.9654, Perplexity: 19.4031
# Epoch [1/1], Step [41200/41412], Loss: 2.8393, Perplexity: 17.1038
# Epoch [1/1], Step [41300/41412], Loss: 3.2162, Perplexity: 24.9343
# Epoch [1/1], Step [41400/41412], Loss: 3.1899, Perplexity: 24.2862
# Epoch [1/1], Step [41412/41412], Loss: 3.3153, Perplexity: 27.5309

# %% [markdown]
# <a id='step3'></a>
# ## Step 3: (Optional) Validate your Model
#
# To assess potential overfitting, one approach is to assess performance on a validation set.  If you decide to do this **optional** task, you are required to first complete all of the steps in the next notebook in the sequence (**3_Inference.ipynb**); as part of that notebook, you will write and test code (specifically, the `sample` method in the `DecoderRNN` class) that uses your RNN decoder to generate captions.  That code will prove incredibly useful here.
#
# If you decide to validate your model, please do not edit the data loader in **data_loader.py**.  Instead, create a new file named **data_loader_val.py** containing the code for obtaining the data loader for the validation data.  You can access:
# - the validation images at filepath `'/opt/cocoapi/images/train2014/'`, and
# - the validation image caption annotation file at filepath `'/opt/cocoapi/annotations/captions_val2014.json'`.
#
# The suggested approach to validating your model involves creating a json file such as [this one](https://github.com/cocodataset/cocoapi/blob/master/results/captions_val2014_fakecap_results.json) containing your model's predicted captions for the validation images.  Then, you can write your own script or use one that you [find online](https://github.com/tylin/coco-caption) to calculate the BLEU score of your model.  You can read more about the BLEU score, along with other evaluation metrics (such as TEOR and Cider) in section 4.1 of [this paper](https://arxiv.org/pdf/1411.4555.pdf).  For more information about how to use the annotation file, check out the [website](http://cocodataset.org/#download) for the COCO dataset.

# %%
# (Optional) TODO: Validate your model.
